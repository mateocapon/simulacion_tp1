# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import norm, stats
import scipy.stats as stats

# %% [markdown]
# ### Distribucion normal de media 10, desvio estandar 2

# %%
def generar_normal(N):
    U1=np.random.rand(N)
    U2=np.random.rand(N)
    S=np.random.rand(N)
    X=[]
    X11=[]

    def f1(u):
     return -1*np.log(U1[i])

    def f2(x):
     return np.exp(-1/2 * (x-1)**2 ) 

    def f3(x,m,v):
      return x*np.sqrt(v)+m

    for i in range (N):
      X1=f1(U1[i])
      if (U2[i] <=f2(X1)):
        X11.append(X1)
        if S[i] <= 0.5:
          X.append(X1)
        else:
           X.append(-1*X1)

    #Distribucion Normal (10, 2)

    b = 10
    c = 2**2

    Z = []
    for i in X:
      Z.append (f3(i,b,c))
    
    
    mu, std = norm.fit(Z)
    bins = 30
    fig, ax = plt.subplots(figsize = (10,6))
    ax.hist(Z,color = 'blue', bins = bins)
    ax.set_ylabel('Valores de Z')
    ax.set_xlabel('Z')
    plt.title('Histograma de Z')
    plt.grid()
    plt.show()
    print ('Media: ',np.mean(Z))
    print ('Varianza: ',np.var(Z))
    
    return Z

# %% [markdown]
# # Prueba de  Kolmogorov Smirnov

# %%
def qq_plot(Z):
    fig, ax = plt.subplots(figsize = (10,6))
    stats.probplot(Z, dist="norm", plot=ax)
    plt.title("Normal Q-Q plot")
    plt.grid()
    plt.show()

def probas_acumuladas(Z, intervalo):
    probabilidades_acumuladas = [] 
    valores = list(np.arange(-3, 3.1, intervalo))
    acumulado = 0
    MU = np.mean(Z)
    SIGMA = np.std(Z)
    N = len(Z)
    for i in valores:
        acumulado = 0
        for valor in Z:
            valor = (valor - MU) / SIGMA
            if valor <= i:
                acumulado += 1
        probabilidades_acumuladas.append(acumulado / N)
    return probabilidades_acumuladas

def tabla_normal_acumulada(intervalo):
    n = 6/intervalo
    domain = np.linspace(-3,3, int(n))
    normal_acumulada = norm.cdf(domain, 0, 1)
    return normal_acumulada
    
def calcular_estadistico(normal_acumulada, probabilidades_acumuladas):
    D = 0
    for index in range(len(normal_acumulada)):
        delta = abs(normal_acumulada[index] - probabilidades_acumuladas[index])
        if delta > D:
            D = delta
    print("Estadistico D: {}".format(D))
    return D

def calcular_q(N):
    q = 1.36/np.sqrt(N)
    print("p-valor: {}".format(q))
    return q

def plotear_distribucion(probabilidades_acumuladas, intervalo):
    fig, ax = plt.subplots(figsize = (10,6))
    valores = list(np.arange(-3, 3.1, intervalo))
    n = 6/intervalo
    domain = np.linspace(-3,3, int(n))
    ax.plot(valores, probabilidades_acumuladas, color = 'blue', label = 'Distribucion acumulada empirica')
    ax.plot(domain, norm.cdf(domain, 0, 1), color = 'red', label = 'Distribucion acumulada teorica')
    plt.title("Distribuciones acumuladas (estandarizada)")
    ax.set_xlabel('Valores de Z')
    ax.set_ylabel('Probabilidad acumulada')
    plt.legend()
    plt.grid()
    plt.show()
        
def test_KS(Z):
    N = len(Z)
    intervalo = 0.01
    probabilidades_acumuladas = probas_acumuladas(Z, intervalo)
    plotear_distribucion(probabilidades_acumuladas, intervalo)
    normal_acumulada = tabla_normal_acumulada(intervalo)
    D = calcular_estadistico(normal_acumulada, probabilidades_acumuladas)
    q = calcular_q(N)
    if (D < q):
        print("\npvalor > D -> No hay evidencia suficiente para asegurar que la distribucion generada no es normal.")
    else:
        print("\nSe puede rechazar la hipotesis: la distribucion no es normal.")

# %%
Z = generar_normal(N = 50)
qq_plot(Z)
test_KS(Z)
# Out:
# Media:  9.846957186306087
# Varianza:  2.608983490609335
# Estadistico D: 0.07597705307135988
# p-valor: 0.2298819572861565
#
# pvalor > D -> No hay evidencia suficiente para asegurar que la distribucion generada no es normal.

# %%
Z = generar_normal(N = 100)
qq_plot(Z)
test_KS(Z)
# Out:
# Media:  10.196546407601938
# Varianza:  3.990705562627117
# Estadistico D: 0.0457049506155523
# p-valor: 0.14838816536047483
#
# pvalor > D -> No hay evidencia suficiente para asegurar que la distribucion generada no es normal.

# %%
Z = generar_normal(N = 1000)
qq_plot(Z)
test_KS(Z)
# Out:
# Media:  9.824617989565919
# Varianza:  3.4061379110587873
# Estadistico D: 0.02207773990340023
# p-valor: 0.049430040764567355
#
# pvalor > D -> No hay evidencia suficiente para asegurar que la distribucion generada no es normal.

# %%
Z = generar_normal(N = 10000)
qq_plot(Z)
test_KS(Z)
# Out:
# Media:  9.97592739582134
# Varianza:  4.007602291996753
# Estadistico D: 0.01038628031279698
# p-valor: 0.0156002699031982
#
# pvalor > D -> No hay evidencia suficiente para asegurar que la distribucion generada no es normal.

# %% [markdown]
# # Conclusión
#
# Se puede ver que el generador de numeros con distribucion normal genera efectivamente numeros distribuidos normalmente. El test muy dificilmente falla, y al graficar se ve efectivamente la forma de la distribucion de numeros genera una campanaa tipica de la distribucion en cuestion. Ademas adjuntamos un grafico QQ, una prueba bastante tipica para comparar dos distribuciones. que efectivamente nos brinda otro argumento mas a favor del generador de numeros.
