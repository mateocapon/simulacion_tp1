# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns
from scipy.stats import chi2

modulo = 2**32
multiplicador = 1013904223
incremento = 1664525
semilla = int((101503+103856+104258+102995)/4)

def generarRandomNormalizada(n):
    x = semilla
    result = []
    for i in range(n):
        result.append(x/modulo)
        x = (x * multiplicador + incremento) % modulo
    return result

N = 100000

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# Previo a resolver el ejercicio, consideraremos cierta propiedades teóricas que son de gran ayuda. En principio se debe considerar: Si (X,Y) es un vector aleatorio con distribucion uniforme sobre el rectangulo [a,b] x [c,d], entonces:
#
# (1) Una traslacion preserva la uniformidad. S = ( X + e, Y + f) se distribuye uniformemente sobre el cuadrado
# [a + e, b + e] x [ c + f , d + f].
#
#
# (2) Una transformacion lineal biyectiva preserva la uniformidad. Es decir, si (U,V) ~ U([-a,a]x [-a,a])
# entonces si (U', V') es el vector aleateorio resultante de una rotacion por un angulo $\theta$ compuesta con una dilatacion o contraccion, (U', V') estara distribuido uniformemente sobre el nuevo espacio.
#
#
# Demostrar (1) es bastante simple, basta pensar en el hecho de que simplemente se esta desplazando la región. Para mostrar (2) basta considerar el método del Jacobiano del cual se deriva que si $ Y = A.X $ , con $ A \in \mathbb R ^{2 \times 2} $ inversible, entonces $ f_{Y}(y) = \frac{f_{X}(x)}{|det(A)|}$
#
# Considerando estas propiedades, dado que sabemos generar muestras en el cuadrado $D =\{(x,y) \in [0,1] \times [0,1]\}$ buscamos una Transformacion T que preserve la uniformidad hacia el rectángulo pedido. Sea entonces $ \overrightarrow{X} \sim U(D) $ e $ \overrightarrow{Y} \sim U(R) $ , donde $R$ es el rectángulo de la figura del ejercicio 3.
#
# Para definir T, la pensaremos como una composicion de distintas transformaciones:
#
# (1) $\overrightarrow{Y}_{1} = T_{1}(\overrightarrow{X}) = 10\overrightarrow{X} \Rightarrow \overrightarrow{Y}_{1} \sim U([0,10] \times [0,10])$
#
#
# (2) $\overrightarrow{Y}_{2} = T_{2}(\overrightarrow{Y}_{1}) = \overrightarrow{Y}_{1} - \overrightarrow{(5, 5)} \Rightarrow \overrightarrow{Y}_{2} \sim U([-5,5] \times [-5,5])$
#
#
# (3) $\overrightarrow{Y}_{3} = T_{3}(\overrightarrow{Y}_{2}) = A . \overrightarrow{Y}_{2} $, donde
#  A = \begin{pmatrix}
#     cos \frac{\pi}{4} & -sen \frac{\pi}{4}  \\
#     sen \frac{\pi}{4} & cos \frac{\pi}{4}  \\
#     \end{pmatrix}
#
# $\Rightarrow \overrightarrow{Y}_{3}$ se distribuye uniformemente sobre el cuadrado de lado 10 con vertices sobre los ejes coordenados y centrado en el origen.
#
#
# (4) $\overrightarrow{Y} = T_{3}(\overrightarrow{Y}_{2}) = \overrightarrow{Y}_{2} + \overrightarrow{(20, 20)} \Rightarrow \overrightarrow{Y} \sim U(R)$
#
# Y por lo tanto habremos terminado de realizar la transformacion.

# %%
def transformacionUno(x, y):
    return (x * 10, y * 10)

def transformacionDos(x, y):
    return(x - 5, y - 5)

def transformacionTres(x, y):
    return((x - y) * np.sqrt(2) / 2,(x + y) *  np.sqrt(2) / 2)

def transformacionFinal(x, y):
    return (x + 20, y + 20)

# %% [markdown]
# ## Ejercicio 3.a
#
# Una vez definidas las funciones, presentamos los ejercicios.

# %%
x = np.random.rand(N)
y = np.random.rand(N)

x, y = transformacionUno(x, y)
x, y = transformacionDos(x, y)
x, y = transformacionTres(x, y)
x, y = transformacionFinal(x, y)

ax = sns.scatterplot( x=x , y=y , s = 10 )
plt.title('Distribucion sobre R con numeros aleatorios de Python')
# Out:
# Text(0.5, 1.0, 'Distribucion sobre R con numeros aleatorios de Python')

# %%
ax = sns.scatterplot( x=x , y=y , s = 10 )
plt.title('Distribucion sobre R con numeros aleatorios de Python')

ax.set_ylim(0, 100)
ax.set_xlim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ## Ejercicio 3.b

# %%
s = generarRandomNormalizada(N*2)
x, y = np.array_split(s,2)

x, y = transformacionUno(x, y)
x, y = transformacionDos(x, y)
x, y = transformacionTres(x, y)
x, y = transformacionFinal(x, y)

ax = sns.scatterplot( x=x , y=y , s = 10 )
plt.title('Distribucion sobre R con numeros pseudo-aleatorios GCL')
# Out:
# Text(0.5, 1.0, 'Distribucion sobre R con numeros pseudo-aleatorios GCL')

# %%
ax = sns.scatterplot( x=x , y=y , s = 10 )
ax.set_ylim(0, 100)
ax.set_xlim(0, 100)
plt.title('Distribucion sobre R con numeros pseudo-aleatorios GCL')
# Out:
# Text(0.5, 1.0, 'Distribucion sobre R con numeros pseudo-aleatorios GCL')

# %% [markdown]
# ## Ejercicio 3.c
#
# Una ventaja de esta Transformacion es que el factor de rendimiento es del 100%, ya que todos las muestras son
# redirijidas mediante una transformacion biyectiva al cuadrado $R$.

# %% [markdown]
# ## Ejercicio 3.d

# %% [markdown]
# En función de realizar un test de hipótesis para verficar que la muestra se distribuye uniformemente, divideremos el área del cuadrado rotado en 10 rectángulos de igual area, modelando asi una muestra discreta con 10 opciones posibles, cuya frecuencia de aparición debiera ser uniforme.
#
# Los cortes los haremos perpendicularmente a los lados del cuadrado que son intersecados por la recta $y = x$. De este modo, separaremos el plano $(x,y)$ en 10 regiones mediante las rectas de pendiente 1, con distancia 1 entre ellas, formando así rectángulos de base 1 y altura 10.
#
# La primera recta pasa por el punto $P = (20, 20) + 4(\frac{\sqrt{2}}{2}, - \frac{\sqrt{2}}{2})$ y tiene pendiente $m = 1$. Entonces sera la recta de ecuacion $ y = x - 4 \sqrt{2}$ y las siguientes seran las rectas desplazadas con distancia entre las mismas de 1.

# %%
intervalo1 = intervalo2 = intervalo3 = intervalo4 = intervalo5 = 0
intervalo6 = intervalo7 = intervalo8 = intervalo9 = intervalo10 = 0

for i in range(len(x)):
    if(x[i] - 4 * np.sqrt(2) > y[i] and x[i] - 5 * np.sqrt(2) < y[i]):
        intervalo1 += 1
    elif(x[i] - 3 * np.sqrt(2) > y[i] and x[i] - 4 * np.sqrt(2) < y[i]):
        intervalo2 += 1
    elif(x[i] - 2 * np.sqrt(2) > y[i] and x[i] - 3 * np.sqrt(2) < y[i]):
        intervalo3 += 1
    elif(x[i] - np.sqrt(2) > y[i]):
        intervalo4 += 1
    elif(x[i] > y[i] ):
        intervalo5 += 1
    elif(x[i] + np.sqrt(2) > y[i]):
        intervalo6 += 1
    elif(x[i] + 2 * np.sqrt(2) > y[i]):
        intervalo7 += 1
    elif(x[i] + 3 * np.sqrt(2) > y[i]):
        intervalo8 += 1
    elif(x[i] + 4 * np.sqrt(2) > y[i]):
        intervalo9 += 1
    elif(x[i] + 5 * np.sqrt(2) > y[i]):
        intervalo10 += 1

f1e = f2e = f3e = f4e = f5e = f6e = f7e = f8e = f9e = f10e = len(x) * 1/10

frecuencias_obtenidas = [ intervalo1, intervalo2, intervalo3, intervalo4, intervalo5, intervalo6, intervalo7, intervalo8, intervalo9, intervalo10 ]
frecuencias_esperadas = [ f1e, f2e, f3e, f4e, f5e, f6e, f7e, f8e, f9e, f10e ]

print(frecuencias_esperadas)
print(frecuencias_obtenidas)
# Out:
# [10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0, 10000.0]
# [9961, 10099, 10081, 9975, 10016, 10048, 10003, 9872, 9964, 9981]

# %% [markdown]
# Realizamos el test de hipotesis Chi Cuadrado

# %%
D2 = sum( ( (frecuencias_obtenidas[i] - frecuencias_esperadas[i])**2 / frecuencias_esperadas[i]) for i in range(len(frecuencias_esperadas) ) )

grados = 10 - 1
alpha = 0.99

limiteSuperior = chi2.ppf( alpha, df=grados )

# %%
if D2 <= limiteSuperior:
    print("El test acepta la hipótesis nula.")
else:
    print("El test rechaza la hipótesis nula")
# Out:
# El test acepta la hipótesis nula.

# %% [markdown]
# ## Ejercicio 3: otra resolucion
#
# Mediante esta resolucion obtenemos un resultado parecido pero con menor factor de rendimiento, es decir, un peor resultado.

# %% [markdown]
# Para poder comparar el factor de rendimiento vamos a hacer el grafico del todos los puntos en el plano y poder compararlos 1 a 1

# %%
hipotenusa = 10
catetos = np.sqrt((hipotenusa**2)/2)

x = np.random.rand(N)
y = np.random.rand(N)

plt.figure(figsize=(15, 8))
ax = sns.scatterplot( x=x , y=y , s = 10 )

# %% [markdown]
# ## Ejecicio 3.a

# %%
hipotenusa = 10
catetos = np.sqrt((hipotenusa**2)/2)

x = np.random.rand(N)
y = np.random.rand(N)

X = []
Y = []

for i in range(N):
    if( y[i] < -x[i]+(0.4-catetos/100) ):
      continue
    if( y[i] > -x[i]+ (0.4+catetos/100) ):
      continue
    if( y[i] > x[i] + catetos/100 ):
      continue
    if( y[i] < x[i] - catetos/100 ):
      continue

    else:
      X.append(x[i])
      Y.append(y[i])

# %%
plt.figure(figsize=(15, 8))
sns.set_theme()
ax = sns.scatterplot( x=X , y=Y , s = 10 )

ax.set_ylim(0, 1)
ax.set_xlim(0, 1)

ax2 = plt.axes([0.95, 0.6, .3, .3])

sns.scatterplot( x=X, y=Y )
ax2.set_title('Zoom del grafico')
ax2.set_xlim([0.1,0.3])
ax2.set_ylim([0.1,0.3])
# Out:
# (0.1, 0.3)

# %% [markdown]
# La figura distribución del vector aleatorio (X, Y) es sin embargo en el cuadrado de lado 10 y centro en (20,20). Entonces, debemos multiplicar por 100.

# %%
X = list(map(lambda x: 100 * x, X))
Y = list(map(lambda x: 100 * x, Y))

# %%
ax = sns.scatterplot( x=X , y=Y , s = 10 )
plt.title('Distribucion sobre R con numeros aleatorios de Numpy')
# Out:
# Text(0.5, 1.0, 'Distribucion sobre R con numeros aleatorios de Numpy')

# %%
assert(len(X) == len(Y))

factorRendimiento = len(X)/N

print("Cantidad de puntos en figura : {} ".format(len(X)))
print("Puntos en figura sobre puntos totales : {} ".format(factorRendimiento))
# Out:
# Cantidad de puntos en figura : 978
# Puntos en figura sobre puntos totales : 0.00978

# %% [markdown]
# ## Ejecicio 3.b

# %%
hipotenusa = 10
catetos = np.sqrt((hipotenusa**2)/2)

s = generarRandomNormalizada(N*2)

x, y = np.array_split(s,2)

X = []
Y = []

for i in range(N):
    if( y[i] < -x[i]+(0.4-catetos/100) ):
      continue
    if( y[i] > -x[i]+ (0.4+catetos/100) ):
      continue
    if( y[i] > x[i] + catetos/100 ):
      continue
    if( y[i] < x[i] - catetos/100 ):
      continue

    else:
      X.append(x[i] * 100)
      Y.append(y[i] * 100)

# %%
plt.figure(figsize=(15, 8))
ax = sns.scatterplot( x=X , y=Y , s = 10 )

ax.set_ylim(0, 100)
ax.set_xlim(0, 100)

ax2 = plt.axes([0.95, 0.6, .3, .3])
sns.set_theme()

sns.scatterplot( x=X, y=Y )
ax2.set_title('Zoom del grafico')
ax2.set_xlim([13, 27])
ax2.set_ylim([13, 27])
# Out:
# (13.0, 27.0)

# %%
assert(len(X) == len(Y))

factorRendimiento = len(X)/N

print("Cantidad de puntos en figura : {} ".format(len(X)))
print("Puntos en figura sobre puntos totales : {} ".format(factorRendimiento))
# Out:
# Cantidad de puntos en figura : 982
# Puntos en figura sobre puntos totales : 0.00982
